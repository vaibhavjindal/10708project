# %% [markdown]
# This is an implementation of the paper Deep Bayesian Active Learning with Image Data using PyTorch and modAL.
#
# modAL is an active learning framework for Python3, designed with modularity, flexibility and extensibility in mind. Built on top of scikit-learn, it allows you to rapidly create active learning workflows with nearly complete freedom. What is more, you can easily replace parts with your custom built solutions, allowing you to design novel algorithms with ease.
#
# Since modAL only supports sklearn models, we will also use [skorch](https://skorch.readthedocs.io/en/stable/), a scikit-learn compatible neural network library that wraps PyTorch.

# %%
# !pip install -U skorch
# !pip install modAL
# !pip install lightning-bolts
# Out:
# Collecting skorch
#   Downloading skorch-0.11.0-py3-none-any.whl (155 kB)
#      |████████████████████████████████| 155 kB 4.1 MB/s
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.7/dist-packages (from skorch) (0.8.9)
# Requirement already satisfied: tqdm>=4.14.0 in /usr/local/lib/python3.7/dist-packages (from skorch) (4.64.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from skorch) (1.4.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from skorch) (1.21.6)
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from skorch) (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.19.1->skorch) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.19.1->skorch) (1.1.0)
# Installing collected packages: skorch
# Successfully installed skorch-0.11.0
# Collecting modAL
#   Downloading modAL-0.4.1-py3-none-any.whl (27 kB)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.7/dist-packages (from modAL) (1.0.2)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from modAL) (1.3.5)
# Requirement already satisfied: scipy>=0.18 in /usr/local/lib/python3.7/dist-packages (from modAL) (1.4.1)
# Requirement already satisfied: numpy>=1.13 in /usr/local/lib/python3.7/dist-packages (from modAL) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.0->modAL) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.0->modAL) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.1.0->modAL) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.18->modAL) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.18->modAL) (1.1.0)
# Installing collected packages: modAL
# Successfully installed modAL-0.4.1
# Collecting lightning-bolts
#   Downloading lightning_bolts-0.5.0-py3-none-any.whl (316 kB)
#      |████████████████████████████████| 316 kB 4.4 MB/s
# Requirement already satisfied: torch>=1.7.1 in /usr/local/lib/python3.7/dist-packages (from lightning-bolts) (1.11.0+cu113)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from lightning-bolts) (21.3)
# Collecting pytorch-lightning>=1.4.0
#   Downloading pytorch_lightning-1.6.2-py3-none-any.whl (582 kB)
#      |████████████████████████████████| 582 kB 40.4 MB/s
# Collecting torchmetrics>=0.4.1
#   Downloading torchmetrics-0.8.1-py3-none-any.whl (408 kB)
#      |████████████████████████████████| 408 kB 49.6 MB/s
# Collecting fsspec[http]!=2021.06.0,>=2021.05.0
#   Downloading fsspec-2022.3.0-py3-none-any.whl (136 kB)
#      |████████████████████████████████| 136 kB 72.2 MB/s
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.4.0->lightning-bolts) (2.8.0)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.4.0->lightning-bolts) (1.21.6)
# Collecting PyYAML>=5.4
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 66.6 MB/s
# Collecting pyDeprecate<0.4.0,>=0.3.1
#   Downloading pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.4.0->lightning-bolts) (4.64.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.4.0->lightning-bolts) (4.2.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.4.0->lightning-bolts) (2.23.0)
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 61.5 MB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->lightning-bolts) (3.0.8)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.4.0->lightning-bolts) (3.17.3)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.4.0->lightning-bolts) (0.37.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.4.0->lightning-bolts) (57.4.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.4.0->lightning-bolts) (3.3.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.4.0->lightning-bolts) (1.35.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.4.0->lightning-bolts) (1.0.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.4.0->lightning-bolts) (0.6.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.4.0->lightning-bolts) (1.44.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.4.0->lightning-bolts) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.4.0->lightning-bolts) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.4.0->lightning-bolts) (1.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from absl-py>=0.4->tensorboard>=2.2.0->pytorch-lightning>=1.4.0->lightning-bolts) (1.15.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.4.0->lightning-bolts) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.4.0->lightning-bolts) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.4.0->lightning-bolts) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.4.0->lightning-bolts) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.4.0->lightning-bolts) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.4.0->lightning-bolts) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.4.0->lightning-bolts) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.4.0->lightning-bolts) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.4.0->lightning-bolts) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.4.0->lightning-bolts) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.4.0->lightning-bolts) (2021.10.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.4.0->lightning-bolts) (3.2.0)
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 67.4 MB/s
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.4.0->lightning-bolts) (21.4.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.4.0->lightning-bolts) (2.0.12)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      |████████████████████████████████| 144 kB 59.5 MB/s
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      |████████████████████████████████| 94 kB 3.5 MB/s
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Installing collected packages: multidict, frozenlist, yarl, asynctest, async-timeout, aiosignal, pyDeprecate, fsspec, aiohttp, torchmetrics, PyYAML, pytorch-lightning, lightning-bolts
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed PyYAML-6.0 aiohttp-3.8.1 aiosignal-1.2.0 async-timeout-4.0.2 asynctest-0.13.0 frozenlist-1.3.0 fsspec-2022.3.0 lightning-bolts-0.5.0 multidict-6.0.2 pyDeprecate-0.3.2 pytorch-lightning-1.6.2 torchmetrics-0.8.1 yarl-1.7.2

# %%
# !mkdir perf_lists_cifar_vae

# %%
PATH = './'

from pl_bolts.datamodules import CIFAR10DataModule, STL10DataModule
from pl_bolts.models.autoencoders import VAE
from pytorch_lightning import Trainer
import matplotlib.pyplot as plt
import numpy as np
import torch
from torchvision import transforms
import torch.nn.functional as F

vae = VAE(input_height=32, first_conv=False)
print(VAE.pretrained_weights_available())

vae = vae.from_pretrained(f'cifar10-resnet18')

vae.freeze()


dm = CIFAR10DataModule(PATH, normalize=True)
dm.prepare_data()
dm.setup("fit")
dataloader = dm.train_dataloader()


mean = torch.tensor(dm.default_transforms().transforms[1].mean)
std = torch.tensor(dm.default_transforms().transforms[1].std)

normalize = transforms.Normalize(mean, std)
unnormalize = transforms.Normalize((-mean / std).tolist(), (1.0 / std).tolist())

def get_new_images(X):
    vae.eval()
    X_hat = vae(normalize(X))
    return unnormalize(X_hat).detach()
# Out:
# ['cifar10-resnet18', 'stl10-resnet18']
# Downloading: "https://pl-bolts-weights.s3.us-east-2.amazonaws.com/vae/vae-cifar10/checkpoints/epoch%3D89.ckpt" to /root/.cache/torch/hub/checkpoints/epoch%3D89.ckpt
#   0%|          | 0.00/230M [00:00<?, ?B/s]
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./cifar-10-python.tar.gz to ./
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/core/datamodule.py:89: LightningDeprecationWarning: DataModule property `train_transforms` was deprecated in v1.5 and will be removed in v1.7.
#   "DataModule property `train_transforms` was deprecated in v1.5 and will be removed in v1.7."
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/core/datamodule.py:108: LightningDeprecationWarning: DataModule property `val_transforms` was deprecated in v1.5 and will be removed in v1.7.
#   "DataModule property `val_transforms` was deprecated in v1.5 and will be removed in v1.7."

# %%
import torch
import numpy as np
from torch import nn
from torch.nn import functional as F
from torch.utils.data import DataLoader
from torchvision.transforms import ToTensor
from torchvision.datasets import CIFAR10
from skorch import NeuralNetClassifier
from modAL.models import ActiveLearner
from torchvision import transforms
# from VAE import VAE

# %% [markdown]
# ### architecture of the network we will be using
#
# We will use the architecture described in the paper.

# %%
# class CNN(nn.Module):
#     def __init__(self,):
#         super(CNN, self).__init__()
#         self.convs = nn.Sequential(
#                                 nn.Conv2d(1,32,4),
#                                 nn.ReLU(),
#                                 nn.Conv2d(32,32,4),
#                                 nn.ReLU(),
#                                 nn.MaxPool2d(2),
#                                 nn.Dropout(0.25)
#         )
#         self.fcs = nn.Sequential(
#                                 nn.Linear(11*11*32,128),
#                                 nn.ReLU(),
#                                 nn.Dropout(0.5),
#                                 nn.Linear(128,10),
#         )

#     def forward(self, x):
#         out = x
#         out = self.convs(out)
#         out = out.view(-1,11*11*32)
#         out = self.fcs(out)
#         return out

input_dim, input_height, input_width = 3, 28, 28
class lenet(nn.Module):  
    def __init__(self):
        super(lenet, self).__init__()
        self.input_height = input_height
        self.input_width = input_width
        self.input_dim = input_dim
        self.class_num = 10

        self.conv1 = nn.Conv2d(self.input_dim, 6, (5, 5), padding=2)
        self.conv2 = nn.Conv2d(6, 16, (5, 5))
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, self.class_num)

    def forward(self, x):
        x = F.max_pool2d(F.relu(self.conv1(x)), (2, 2))
        x = F.max_pool2d(F.relu(self.conv2(x)), (2, 2))
        x = x.view(-1, self.num_flat_features(x))
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

    def num_flat_features(self, x):
        size = x.size()[1:]
        num_features = 1
        for s in size:
            num_features *= s
        return num_features

# class CNN(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.conv1 = nn.Conv2d(3, 6, 5)
#         self.pool = nn.MaxPool2d(2, 2)
#         self.conv2 = nn.Conv2d(6, 16, 5)
#         self.fc1 = nn.Linear(16 * 5 * 5, 120)
#         self.fc2 = nn.Linear(120, 84)
#         self.fc3 = nn.Linear(84, 10)

#     def forward(self, x):
#         x = self.pool(F.relu(self.conv1(x)))
#         x = self.pool(F.relu(self.conv2(x)))
#         x = torch.flatten(x, 1) # flatten all dimensions except batch
#         x = F.relu(self.fc1(x))
#         x = F.relu(self.fc2(x))
#         x = self.fc3(x)
#         return x

# %% [markdown]
# ### read training data

# %%
cifar10_train = CIFAR10('.', train=True, download=True, transform=transforms.Compose([transforms.ToTensor(), transforms.Resize(size=(28, 28))]))
cifar10_test  = CIFAR10('.', train=False,download=True, transform=transforms.Compose([transforms.ToTensor(), transforms.Resize(size=(28, 28))]))
traindataloader = DataLoader(cifar10_train, shuffle=True, batch_size=60000)
testdataloader  = DataLoader(cifar10_train, shuffle=True, batch_size=10000)
X_train, y_train = next(iter(traindataloader))
X_test , y_test  = next(iter(testdataloader))
X_train, y_train = X_train.detach().cpu().numpy(), y_train.detach().cpu().numpy()
X_test, y_test = X_test.detach().cpu().numpy(), y_test.detach().cpu().numpy()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
X_train.shape
# Out:
# (50000, 3, 28, 28)

# %% [markdown]
# ### preprocessing

# %%
# X_train = X_train.reshape(60000, 1, 28, 28)
# X_test = X_test.reshape(10000, 1, 28, 28)

# %% [markdown]
# ### initial labelled data
# We initialize the labelled set with 100 balanced randomly sampled examples

# %%
initial_idx = np.array([],dtype=int)
for i in range(10):
    idx = np.random.choice(np.where(y_train==i)[0], size=10, replace=False)
    initial_idx = np.concatenate((initial_idx, idx))

X_initial = X_train[initial_idx]
y_initial = y_train[initial_idx]

# %% [markdown]
# ### initial unlabelled pool

# %%
# X_pool = np.delete(X_train, initial_idx, axis=0)
# y_pool = np.delete(y_train, initial_idx, axis=0)
X_pool = np.copy(X_train)
y_pool = np.copy(y_train)

# %% [markdown]
# ## Query Strategies

# %% [markdown]
# ### Uniform
# All the acquisition function we will use will be compared to the uniform acquisition function $\mathbb{U}_{[0,1]}$ which will be our baseline that we would like to beat.

# %%
def uniform(learner, X, n_instances=1):
    query_idx = np.random.choice(range(len(X)), size=n_instances, replace=False)
    return query_idx, X[query_idx]

# %% [markdown]
# ### Entropy
# Our first acquisition function is the entropy:
# $$ \mathbb{H} = - \sum_{c} p_c \log(p_c)$$
# where $p_c$ is the probability predicted for class c. This is approximated by:
# \begin{align}
# p_c &= \frac{1}{T} \sum_t p_{c}^{(t)}
# \end{align}
# where $p_{c}^{t}$ is the probability predicted for class c at the t th feedforward pass.

# %%
def max_entropy(learner, X, n_instances=1, T=100):
    random_subset = np.random.choice(range(len(X)), size=2000, replace=False)
    with torch.no_grad():
        outputs = np.stack([torch.softmax(learner.estimator.forward(X[random_subset], training=True),dim=-1).cpu().numpy()
                            for t in range(20)])
    pc = outputs.mean(axis=0)
    acquisition = (-pc*np.log(pc + 1e-10)).sum(axis=-1)
    idx = (-acquisition).argsort()[:n_instances]
    query_idx = random_subset[idx]
    return query_idx, X[query_idx]

# %%
def bald(learner, X, n_instances=1, T=100):
    random_subset = np.random.choice(range(len(X)), size=2000, replace=False)
    with torch.no_grad():
        outputs = np.stack([torch.softmax(learner.estimator.forward(X[random_subset], training=True),dim=-1).cpu().numpy()
                            for t in range(20)])
    pc = outputs.mean(axis=0)
    H   = (-pc*np.log(pc + 1e-10)).sum(axis=-1)
    E_H = - np.mean(np.sum(outputs * np.log(outputs + 1e-10), axis=-1), axis=0)  # [batch size]
    acquisition = H - E_H
    idx = (-acquisition).argsort()[:n_instances]
    query_idx = random_subset[idx]
    return query_idx, X[query_idx]

# %%
def save_list(input_list, name):
    with open("perf_lists_cifar_vae/" + name, 'w') as f:
        for val in input_list:
            f.write("%s\n" % val)

# %% [markdown]
# ### Active Learning Procedure

# %%
def active_learning_procedure_vae(query_strategy,
                              X_test,
                              y_test,
                              X_pool,
                              y_pool,
                              X_initial,
                              y_initial,
                              estimator,
                              n_queries=150,
                              n_instances=100):
    learner = ActiveLearner(estimator=estimator,
                            X_training=X_initial,
                            y_training=y_initial,
                            query_strategy=query_strategy,
                           )
    perf_hist = [learner.score(X_test, y_test)]
    X_rolling, y_rolling = np.copy(X_initial), np.copy(y_initial)
    for index in range(n_queries):
        query_idx, query_instance = learner.query(X_pool, n_instances)

        new_samples = get_new_images(torch.tensor(X_pool[query_idx]))
        new_samples = F.interpolate(new_samples, size=28)
        new_samples = new_samples.detach().cpu().numpy()
        new_samples = np.concatenate((new_samples, X_pool[query_idx]))
        new_labels = np.concatenate((y_pool[query_idx], y_pool[query_idx]))

        X_rolling, y_rolling = np.concatenate((X_rolling, new_samples), axis=0), np.concatenate((y_rolling, new_labels))
        learner.fit(X_rolling, y_rolling)
        X_pool = np.delete(X_pool, query_idx, axis=0)
        y_pool = np.delete(y_pool, query_idx, axis=0)
        model_accuracy = learner.score(X_test, y_test)
        print('Accuracy after query {n}: {acc:0.4f}'.format(n=index + 1, acc=model_accuracy))
        perf_hist.append(model_accuracy)
    return perf_hist

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
estimator = NeuralNetClassifier(lenet,
                                max_epochs=50,
                                batch_size=100,
                                lr=1.0,
                                optimizer=torch.optim.Adadelta,
                                optimizer__rho=0.9,
                                optimizer__eps=1e-6,
                                criterion=torch.nn.CrossEntropyLoss,
                                train_split=None,
                                verbose=0,
                                device=device)
uniform_perf_hist = active_learning_procedure_vae(uniform,
                                              X_test,
                                              y_test,
                                              X_pool,
                                              y_pool,
                                              X_initial,
                                              y_initial,
                                              estimator,
                                             n_instances=100)
# save_list(uniform_perf_hist, "uniform_perf_hist")
# Out:
# Accuracy after query 1: 0.2139
# Accuracy after query 2: 0.2224
# Accuracy after query 3: 0.2912
# Accuracy after query 4: 0.3201
# Accuracy after query 5: 0.3286
# Accuracy after query 6: 0.3105
# Accuracy after query 7: 0.2769
# Accuracy after query 8: 0.3504
# Accuracy after query 9: 0.3484
# Accuracy after query 10: 0.2954
# Accuracy after query 11: 0.3288
# Accuracy after query 12: 0.3437
# Accuracy after query 13: 0.3315
# Accuracy after query 14: 0.3588
# Accuracy after query 15: 0.3621
# Accuracy after query 16: 0.3506
# Accuracy after query 17: 0.3073
# Accuracy after query 18: 0.3836
# Accuracy after query 19: 0.3587
# Accuracy after query 20: 0.3523
# Accuracy after query 21: 0.3484
# Accuracy after query 22: 0.3709
# Accuracy after query 23: 0.3934
# Accuracy after query 24: 0.3699
# Accuracy after query 25: 0.3885
# Accuracy after query 26: 0.3785
# Accuracy after query 27: 0.3944
# Accuracy after query 28: 0.3756
# Accuracy after query 29: 0.3909
# Accuracy after query 30: 0.3906
# Accuracy after query 31: 0.4010
# Accuracy after query 32: 0.3893
# Accuracy after query 33: 0.4195
# Accuracy after query 34: 0.3934
# Accuracy after query 35: 0.4050
# Accuracy after query 36: 0.4051
# Accuracy after query 37: 0.4017
# Accuracy after query 38: 0.3813
# Accuracy after query 39: 0.3962
# Accuracy after query 40: 0.4288
# Accuracy after query 41: 0.4179
# Accuracy after query 42: 0.4231
# Accuracy after query 43: 0.4231
# Accuracy after query 44: 0.4202
# Accuracy after query 45: 0.4278
# Accuracy after query 46: 0.4224
# Accuracy after query 47: 0.4073
# Accuracy after query 48: 0.4183
# Accuracy after query 49: 0.4241
# Accuracy after query 50: 0.4264
# Accuracy after query 51: 0.4369
# Accuracy after query 52: 0.4367
# Accuracy after query 53: 0.4465
# Accuracy after query 54: 0.4329
# Accuracy after query 55: 0.4239
# Accuracy after query 56: 0.4336
# Accuracy after query 57: 0.4541
# Accuracy after query 58: 0.4612
# Accuracy after query 59: 0.4441
# Accuracy after query 60: 0.4320
# Accuracy after query 61: 0.4438
# Accuracy after query 62: 0.4300
# Accuracy after query 63: 0.4269
# Accuracy after query 64: 0.4464
# Accuracy after query 65: 0.4427
# Accuracy after query 66: 0.4284
# Accuracy after query 67: 0.4606
# Accuracy after query 68: 0.4607
# Accuracy after query 69: 0.4438
# Accuracy after query 70: 0.4267
# Accuracy after query 71: 0.4533
# Accuracy after query 72: 0.4492
# Accuracy after query 73: 0.4362
# Accuracy after query 74: 0.4727
# Accuracy after query 75: 0.4929
# Accuracy after query 76: 0.4493
# Accuracy after query 77: 0.4674
# Accuracy after query 78: 0.4540
# Accuracy after query 79: 0.4733
# Accuracy after query 80: 0.4447
# Accuracy after query 81: 0.4481
# Accuracy after query 82: 0.4551
# Accuracy after query 83: 0.4777
# Accuracy after query 84: 0.4626
# Accuracy after query 85: 0.4829
# Accuracy after query 86: 0.4838
# Accuracy after query 87: 0.4678
# Accuracy after query 88: 0.4624
# Accuracy after query 89: 0.4625
# Accuracy after query 90: 0.4647
# Accuracy after query 91: 0.4377
# Accuracy after query 92: 0.4878
# Accuracy after query 93: 0.4650
# Accuracy after query 94: 0.4976
# Accuracy after query 95: 0.4840
# Accuracy after query 96: 0.4790
# Accuracy after query 97: 0.4856
# Accuracy after query 98: 0.4775
# Accuracy after query 99: 0.4807
# Accuracy after query 100: 0.4926
# Accuracy after query 101: 0.5010
# Accuracy after query 102: 0.4946
# Accuracy after query 103: 0.5012
# Accuracy after query 104: 0.4820
# Accuracy after query 105: 0.4905
# Accuracy after query 106: 0.4730
# Accuracy after query 107: 0.5040
# Accuracy after query 108: 0.4988
# Accuracy after query 109: 0.5166
# Accuracy after query 110: 0.4896
# Accuracy after query 111: 0.4962
# Accuracy after query 112: 0.4967
# Accuracy after query 113: 0.4837
# Accuracy after query 114: 0.5067
# Accuracy after query 115: 0.5078
# Accuracy after query 116: 0.5074
# Accuracy after query 117: 0.5054
# Accuracy after query 118: 0.5145
# Accuracy after query 119: 0.4730
# Accuracy after query 120: 0.4980
# Accuracy after query 121: 0.4846
# Accuracy after query 122: 0.5036
# Accuracy after query 123: 0.4923
# Accuracy after query 124: 0.5197
# Accuracy after query 125: 0.5104
# Accuracy after query 126: 0.5212
# Accuracy after query 127: 0.4869
# Accuracy after query 128: 0.5228
# Accuracy after query 129: 0.5054
# Accuracy after query 130: 0.5145
# Accuracy after query 131: 0.5336
# Accuracy after query 132: 0.5163
# Accuracy after query 133: 0.4951
# Accuracy after query 134: 0.5138
# Accuracy after query 135: 0.5342
# Accuracy after query 136: 0.5433
# Accuracy after query 137: 0.5044
# Accuracy after query 138: 0.5121
# Accuracy after query 139: 0.5210
# Accuracy after query 140: 0.5235
# Accuracy after query 141: 0.5113
# Accuracy after query 142: 0.5201
# Accuracy after query 143: 0.5115
# Accuracy after query 144: 0.5399
# Accuracy after query 145: 0.5404
# Accuracy after query 146: 0.5230
# Accuracy after query 147: 0.5318
# Accuracy after query 148: 0.4781
# Accuracy after query 149: 0.5355
# Accuracy after query 150: 0.5484

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
estimator = NeuralNetClassifier(lenet,
                                max_epochs=50,
                                batch_size=100,
                                lr=1.0,
                                optimizer=torch.optim.Adadelta,
                                optimizer__rho=0.9,
                                optimizer__eps=1e-6,
                                criterion=torch.nn.CrossEntropyLoss,
                                train_split=None,
                                verbose=0,
                                device=device)
bald_perf_hist = active_learning_procedure_vae(bald,
                                              X_test,
                                              y_test,
                                              X_pool,
                                              y_pool,
                                              X_initial,
                                              y_initial,
                                              estimator,
                                             n_instances=100)
save_list(bald_perf_hist, "bald_perf_hist")
# Out:
# Accuracy after query 1: 0.2103
# Accuracy after query 2: 0.2152
# Accuracy after query 3: 0.2865
# Accuracy after query 4: 0.3021
# Accuracy after query 5: 0.3024
# Accuracy after query 6: 0.3329
# Accuracy after query 7: 0.3369
# Accuracy after query 8: 0.3146
# Accuracy after query 9: 0.3347
# Accuracy after query 10: 0.3345
# Accuracy after query 11: 0.3001
# Accuracy after query 12: 0.3361
# Accuracy after query 13: 0.3358
# Accuracy after query 14: 0.3449
# Accuracy after query 15: 0.3514
# Accuracy after query 16: 0.3656
# Accuracy after query 17: 0.3535
# Accuracy after query 18: 0.3547
# Accuracy after query 19: 0.3303
# Accuracy after query 20: 0.3768
# Accuracy after query 21: 0.3762
# Accuracy after query 22: 0.3669
# Accuracy after query 23: 0.3568
# Accuracy after query 24: 0.3909
# Accuracy after query 25: 0.3662
# Accuracy after query 26: 0.3672
# Accuracy after query 27: 0.3901
# Accuracy after query 28: 0.3929
# Accuracy after query 29: 0.3590
# Accuracy after query 30: 0.3849
# Accuracy after query 31: 0.3870
# Accuracy after query 32: 0.4050
# Accuracy after query 33: 0.4034
# Accuracy after query 34: 0.4102
# Accuracy after query 35: 0.3967
# Accuracy after query 36: 0.3997
# Accuracy after query 37: 0.4091
# Accuracy after query 38: 0.4146
# Accuracy after query 39: 0.3965
# Accuracy after query 40: 0.4217
# Accuracy after query 41: 0.4089
# Accuracy after query 42: 0.4020
# Accuracy after query 43: 0.4080
# Accuracy after query 44: 0.4290
# Accuracy after query 45: 0.3897
# Accuracy after query 46: 0.4256
# Accuracy after query 47: 0.4258
# Accuracy after query 48: 0.4085
# Accuracy after query 49: 0.4335
# Accuracy after query 50: 0.4314
# Accuracy after query 51: 0.4119
# Accuracy after query 52: 0.4202
# Accuracy after query 53: 0.4374
# Accuracy after query 54: 0.4262
# Accuracy after query 55: 0.4223
# Accuracy after query 56: 0.4330
# Accuracy after query 57: 0.4265
# Accuracy after query 58: 0.4462
# Accuracy after query 59: 0.4239
# Accuracy after query 60: 0.4378
# Accuracy after query 61: 0.4434
# Accuracy after query 62: 0.4536
# Accuracy after query 63: 0.4453
# Accuracy after query 64: 0.4584
# Accuracy after query 65: 0.4394
# Accuracy after query 66: 0.4594
# Accuracy after query 67: 0.4666
# Accuracy after query 68: 0.4652
# Accuracy after query 69: 0.4475
# Accuracy after query 70: 0.4684
# Accuracy after query 71: 0.4480
# Accuracy after query 72: 0.4652
# Accuracy after query 73: 0.4571
# Accuracy after query 74: 0.4583
# Accuracy after query 75: 0.4773
# Accuracy after query 76: 0.4774
# Accuracy after query 77: 0.4294
# Accuracy after query 78: 0.4757
# Accuracy after query 79: 0.4664
# Accuracy after query 80: 0.4763
# Accuracy after query 81: 0.4805
# Accuracy after query 82: 0.4669
# Accuracy after query 83: 0.4478
# Accuracy after query 84: 0.4641
# Accuracy after query 85: 0.4708
# Accuracy after query 86: 0.4854
# Accuracy after query 87: 0.4525
# Accuracy after query 88: 0.4785
# Accuracy after query 89: 0.4825
# Accuracy after query 90: 0.4654
# Accuracy after query 91: 0.4788
# Accuracy after query 92: 0.4617
# Accuracy after query 93: 0.4361
# Accuracy after query 94: 0.4670
# Accuracy after query 95: 0.4990
# Accuracy after query 96: 0.4813
# Accuracy after query 97: 0.4888
# Accuracy after query 98: 0.4790
# Accuracy after query 99: 0.4812
# Accuracy after query 100: 0.5021
# Accuracy after query 101: 0.4726
# Accuracy after query 102: 0.4820
# Accuracy after query 103: 0.4849
# Accuracy after query 104: 0.4837
# Accuracy after query 105: 0.4914
# Accuracy after query 106: 0.5195
# Accuracy after query 107: 0.5265
# Accuracy after query 108: 0.4619
# Accuracy after query 109: 0.4917
# Accuracy after query 110: 0.5023
# Accuracy after query 111: 0.5142
# Accuracy after query 112: 0.4684
# Accuracy after query 113: 0.4893
# Accuracy after query 114: 0.4977
# Accuracy after query 115: 0.4897
# Accuracy after query 116: 0.5124
# Accuracy after query 117: 0.5205
# Accuracy after query 118: 0.4935
# Accuracy after query 119: 0.5103
# Accuracy after query 120: 0.5358
# Accuracy after query 121: 0.5144
# Accuracy after query 122: 0.5014
# Accuracy after query 123: 0.5256
# Accuracy after query 124: 0.5037
# Accuracy after query 125: 0.5199
# Accuracy after query 126: 0.5090
# Accuracy after query 127: 0.5125
# Accuracy after query 128: 0.4908
# Accuracy after query 129: 0.5211
# Accuracy after query 130: 0.5018
# Accuracy after query 131: 0.5354
# Accuracy after query 132: 0.5170
# Accuracy after query 133: 0.5131
# Accuracy after query 134: 0.5250
# Accuracy after query 135: 0.5307
# Accuracy after query 136: 0.5064
# Accuracy after query 137: 0.5357
# Accuracy after query 138: 0.5189
# Accuracy after query 139: 0.5295
# Accuracy after query 140: 0.5291
# Accuracy after query 141: 0.5057
# Accuracy after query 142: 0.5221
# Accuracy after query 143: 0.5229
# Accuracy after query 144: 0.5173
# Accuracy after query 145: 0.5737
# Accuracy after query 146: 0.5205
# Accuracy after query 147: 0.5292
# Accuracy after query 148: 0.5421
# Accuracy after query 149: 0.5333
# Accuracy after query 150: 0.5427

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
estimator = NeuralNetClassifier(lenet,
                                max_epochs=50,
                                batch_size=100,
                                lr=1.0,
                                optimizer=torch.optim.Adadelta,
                                optimizer__rho=0.9,
                                optimizer__eps=1e-6,
                                criterion=torch.nn.CrossEntropyLoss,
                                train_split=None,
                                verbose=0,
                                device=device)
entropy_perf_hist = active_learning_procedure_vae(max_entropy,
                                              X_test,
                                              y_test,
                                              X_pool,
                                              y_pool,
                                              X_initial,
                                              y_initial,
                                              estimator,
                                             n_instances=100)
save_list(entropy_perf_hist, "entropy_perf_hist")
# Out:
# Accuracy after query 1: 0.2386
# Accuracy after query 2: 0.2253
# Accuracy after query 3: 0.2444
# Accuracy after query 4: 0.2487
# Accuracy after query 5: 0.2692
# Accuracy after query 6: 0.2924
# Accuracy after query 7: 0.3336
# Accuracy after query 8: 0.3301
# Accuracy after query 9: 0.3145
# Accuracy after query 10: 0.3087
# Accuracy after query 11: 0.3456
# Accuracy after query 12: 0.3345
# Accuracy after query 13: 0.3520
# Accuracy after query 14: 0.3542
# Accuracy after query 15: 0.3103
# Accuracy after query 16: 0.3313
# Accuracy after query 17: 0.3536
# Accuracy after query 18: 0.3294
# Accuracy after query 19: 0.3010
# Accuracy after query 20: 0.3529
# Accuracy after query 21: 0.3613
# Accuracy after query 22: 0.3610
# Accuracy after query 23: 0.3588
# Accuracy after query 24: 0.3798
# Accuracy after query 25: 0.3680
# Accuracy after query 26: 0.3481
# Accuracy after query 27: 0.3732
# Accuracy after query 28: 0.3783
# Accuracy after query 29: 0.3682
# Accuracy after query 30: 0.4093
# Accuracy after query 31: 0.3612
# Accuracy after query 32: 0.3465
# Accuracy after query 33: 0.3632
# Accuracy after query 34: 0.3987
# Accuracy after query 35: 0.3989
# Accuracy after query 36: 0.3921
# Accuracy after query 37: 0.4099
# Accuracy after query 38: 0.4031
# Accuracy after query 39: 0.3999
# Accuracy after query 40: 0.3959
# Accuracy after query 41: 0.4133
# Accuracy after query 42: 0.3714
# Accuracy after query 43: 0.3967
# Accuracy after query 44: 0.4135
# Accuracy after query 45: 0.4194
# Accuracy after query 46: 0.4035
# Accuracy after query 47: 0.4228
# Accuracy after query 48: 0.4367
# Accuracy after query 49: 0.4212
# Accuracy after query 50: 0.4280
# Accuracy after query 51: 0.4040
# Accuracy after query 52: 0.3991
# Accuracy after query 53: 0.4177
# Accuracy after query 54: 0.4382
# Accuracy after query 55: 0.4251
# Accuracy after query 56: 0.3952
# Accuracy after query 57: 0.4346
# Accuracy after query 58: 0.4280
# Accuracy after query 59: 0.4135
# Accuracy after query 60: 0.4109
# Accuracy after query 61: 0.4705
# Accuracy after query 62: 0.4475
# Accuracy after query 63: 0.4569
# Accuracy after query 64: 0.4292
# Accuracy after query 65: 0.4417
# Accuracy after query 66: 0.4394
# Accuracy after query 67: 0.4594
# Accuracy after query 68: 0.4467
# Accuracy after query 69: 0.4494
# Accuracy after query 70: 0.4614
# Accuracy after query 71: 0.4304
# Accuracy after query 72: 0.4392
# Accuracy after query 73: 0.4446
# Accuracy after query 74: 0.4513
# Accuracy after query 75: 0.4435
# Accuracy after query 76: 0.4520
# Accuracy after query 77: 0.4665
# Accuracy after query 78: 0.4513
# Accuracy after query 79: 0.4599
# Accuracy after query 80: 0.4538
# Accuracy after query 81: 0.4488
# Accuracy after query 82: 0.4464
# Accuracy after query 83: 0.4630
# Accuracy after query 84: 0.4725
# Accuracy after query 85: 0.4790
# Accuracy after query 86: 0.5040
# Accuracy after query 87: 0.4670
# Accuracy after query 88: 0.4469
# Accuracy after query 89: 0.4879
# Accuracy after query 90: 0.4822
# Accuracy after query 91: 0.4283
# Accuracy after query 92: 0.4540
# Accuracy after query 93: 0.4722
# Accuracy after query 94: 0.4770
# Accuracy after query 95: 0.4723
# Accuracy after query 96: 0.4769
# Accuracy after query 97: 0.4932
# Accuracy after query 98: 0.4699
# Accuracy after query 99: 0.4619
# Accuracy after query 100: 0.4898
# Accuracy after query 101: 0.4896
# Accuracy after query 102: 0.4768
# Accuracy after query 103: 0.4743
# Accuracy after query 104: 0.4787
# Accuracy after query 105: 0.4750
# Accuracy after query 106: 0.5031
# Accuracy after query 107: 0.4954
# Accuracy after query 108: 0.4750
# Accuracy after query 109: 0.4713
# Accuracy after query 110: 0.4943
# Accuracy after query 111: 0.5009
# Accuracy after query 112: 0.5162
# Accuracy after query 113: 0.5124
# Accuracy after query 114: 0.4855
# Accuracy after query 115: 0.5224
# Accuracy after query 116: 0.4927
# Accuracy after query 117: 0.4854
# Accuracy after query 118: 0.5008
# Accuracy after query 119: 0.5320
# Accuracy after query 120: 0.4915
# Accuracy after query 121: 0.4450
# Accuracy after query 122: 0.5398
# Accuracy after query 123: 0.5341
# Accuracy after query 124: 0.4928
# Accuracy after query 125: 0.5377
# Accuracy after query 126: 0.5116
# Accuracy after query 127: 0.5000
# Accuracy after query 128: 0.5060
# Accuracy after query 129: 0.5195
# Accuracy after query 130: 0.4935
# Accuracy after query 131: 0.4946
# Accuracy after query 132: 0.4973
# Accuracy after query 133: 0.5134
# Accuracy after query 134: 0.5106
# Accuracy after query 135: 0.5196
# Accuracy after query 136: 0.5243
# Accuracy after query 137: 0.5286
# Accuracy after query 138: 0.5167
# Accuracy after query 139: 0.5326
# Accuracy after query 140: 0.5281
# Accuracy after query 141: 0.5093
# Accuracy after query 142: 0.5115
# Accuracy after query 143: 0.5111
# Accuracy after query 144: 0.5332
# Accuracy after query 145: 0.5371
# Accuracy after query 146: 0.5237
# Accuracy after query 147: 0.5542
# Accuracy after query 148: 0.5109
# Accuracy after query 149: 0.5264
# Accuracy after query 150: 0.5224
